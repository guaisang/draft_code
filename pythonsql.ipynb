# %%
import pandas as pd
from pandas.io import sql as spl
import sqlalchemy as sa

# %%
remote_engine = sa.create_engine('postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com:5432/northwind')

# %%
re = remote_engine

# %%
check_tables = "select table_name from information_schema.tables where table_schema not in ('pg_catalog', 'information_schema')"

# %%
tables = sql.read_sql(check_tables, re)

# %%
tables
# Out:
#               table_name
# 0             categories
# 1      full_order_table5
# 2                     fo
# 3             table_join
# 4             full_order
# 5   customercustomerdemo
# 6   customerdemographics
# 7              customers
# 8              employees
# 9    employeeterritories
# 10         order_details
# 11                orders
# 12              products
# 13                region
# 14              shippers
# 15          shippers_tmp
# 16             suppliers
# 17           territories
# 18              usstates
# 19                table1
# 20                movies
# 21               ratings
# 22      categoriesmerged
# 23           order_table
# 24              full_ord
# 25             new_table
# 26      full_order_table
# 27     full_order_table2
# 28     full_order_table3
# 29     full_order_table4
# 30            temp_table
# 31          full_orders_
# 32           fullorders_
# 33          fullorders__
# 34            fullorders
# 35          descriptions
# ...

# %%
customers = sql.read_sql('select * from customers', re)

# %%
customers
# Out:
#    CustomerID                           CompanyName              ContactName  \
# 0       ALFKI                   Alfreds Futterkiste             Maria Anders
# 1       ANATR    Ana Trujillo Emparedados y helados             Ana Trujillo
# 2       ANTON               Antonio Moreno Taquería           Antonio Moreno
# 3       AROUT                       Around the Horn             Thomas Hardy
# 4       BERGS                    Berglunds snabbköp       Christina Berglund
# 5       BLAUS               Blauer See Delikatessen               Hanna Moos
# 6       BLONP              Blondesddsl père et fils       Frédérique Citeaux
# 7       BOLID             Bólido Comidas preparadas            Martín Sommer
# 8       BONAP                              Bon app'         Laurence Lebihan
# 9       BOTTM                 Bottom-Dollar Markets        Elizabeth Lincoln
# 10      BSBEV                         B's Beverages        Victoria Ashworth
# ...

# %%
orders = sql.read_sql('select * from orders', re)

# %%
orders
# Out:
#      OrderID CustomerID  EmployeeID   OrderDate RequiredDate ShippedDate  \
# 0      10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
# 1      10249      TOMSP           6  1996-07-05   1996-08-16  1996-07-10
# 2      10250      HANAR           4  1996-07-08   1996-08-05  1996-07-12
# 3      10251      VICTE           3  1996-07-08   1996-08-05  1996-07-15
# 4      10252      SUPRD           4  1996-07-09   1996-08-06  1996-07-11
# 5      10253      HANAR           3  1996-07-10   1996-07-24  1996-07-16
# 6      10254      CHOPS           5  1996-07-11   1996-08-08  1996-07-23
# 7      10255      RICSU           9  1996-07-12   1996-08-09  1996-07-15
# 8      10256      WELLI           3  1996-07-15   1996-08-12  1996-07-17
# 9      10257      HILAA           4  1996-07-16   1996-08-13  1996-07-22
# 10     10258      ERNSH           1  1996-07-17   1996-08-14  1996-07-23
# 11     10259      CENTC           4  1996-07-18   1996-08-15  1996-07-25
# ...

# %%
cus_order = sql.read_sql(
    'select "OrderID", orders."CustomerID", "OrderDate", "ContactName" from orders left join customers on orders."CustomerID"=customers."CustomerID"', re)

# %%
cus_order
# Out:
#      OrderID CustomerID   OrderDate           ContactName
# 0      10248      VINET  1996-07-04          Paul Henriot
# 1      10249      TOMSP  1996-07-05         Karin Josephs
# 2      10250      HANAR  1996-07-08          Mario Pontes
# 3      10251      VICTE  1996-07-08          Mary Saveley
# 4      10252      SUPRD  1996-07-09      Pascale Cartrain
# 5      10253      HANAR  1996-07-10          Mario Pontes
# 6      10254      CHOPS  1996-07-11             Yang Wang
# 7      10255      RICSU  1996-07-12          Michael Holz
# 8      10256      WELLI  1996-07-15         Paula Parente
# 9      10257      HILAA  1996-07-16      Carlos Hernández
# 10     10258      ERNSH  1996-07-17         Roland Mendel
# 11     10259      CENTC  1996-07-18       Francisco Chang
# 12     10260      OTTIK  1996-07-19   Henriette Pfalzheim
# 13     10261      QUEDE  1996-07-19      Bernardo Batista
# 14     10262      RATTC  1996-07-22          Paula Wilson
# ...
